# %%
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df = df.drop(['placed'], axis=1)

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks
# 0  7.19                  26.0
# 1  7.46                  38.0
# 2  7.54                  40.0
# 3  6.42                   8.0
# 4  7.23                  17.0

# %%
df.shape
# Out:
# (1000, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['placement_exam_marks'])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(1,11):
  km = KMeans(n_clusters=i)
  km.fit_predict(df)
  wcss.append(km.inertia_)

# %%
wcss
# Out:
# [366001.32586239965,
#  115822.24039173221,
#  56348.9347420704,
#  35481.26687153134,
#  23148.996488119148,
#  15536.900119403232,
#  11851.874862302953,
#  9448.714413232366,
#  8082.835384300327,
#  6438.67212810834]

# %%
plt.plot(range(1,11),wcss)

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=6)

y_means = km.fit_predict(X)

# %%
y_means
# Out:
# array([4, 1, 1, 2, 2, 4, 2, 1, 1, 0, 2, 2, 2, 4, 3, 4, 4, 4, 4, 4, 3, 1,
#        3, 2, 2, 5, 2, 3, 4, 2, 2, 3, 2, 4, 2, 2, 2, 2, 4, 2, 0, 1, 5, 5,
#        3, 2, 2, 3, 1, 4, 4, 4, 4, 1, 1, 2, 2, 4, 3, 1, 1, 0, 4, 4, 3, 4,
#        1, 4, 1, 3, 2, 4, 4, 2, 2, 3, 2, 4, 2, 4, 3, 3, 2, 4, 1, 4, 4, 4,
#        1, 2, 2, 2, 5, 1, 4, 1, 4, 3, 0, 4, 3, 4, 4, 4, 3, 2, 4, 2, 2, 4,
#        1, 1, 2, 2, 0, 1, 4, 2, 3, 1, 3, 4, 3, 3, 1, 3, 1, 4, 4, 1, 3, 4,
#        4, 5, 0, 3, 2, 3, 2, 2, 4, 4, 1, 1, 2, 4, 4, 2, 3, 5, 4, 2, 3, 2,
#        3, 2, 1, 0, 3, 4, 2, 3, 0, 1, 1, 2, 5, 3, 1, 2, 1, 1, 3, 3, 4, 4,
#        1, 1, 1, 3, 4, 1, 0, 4, 1, 1, 5, 2, 3, 2, 4, 2, 1, 2, 1, 3, 1, 4,
#        3, 4, 4, 2, 3, 3, 2, 3, 4, 2, 2, 1, 4, 2, 5, 4, 5, 4, 1, 2, 3, 2,
#        2, 4, 0, 2, 4, 2, 4, 4, 2, 2, 2, 1, 1, 1, 1, 3, 1, 3, 0, 2, 1, 4,
#        3, 3, 3, 5, 4, 3, 3, 3, 2, 3, 3, 0, 5, 2, 3, 0, 2, 2, 5, 2, 2, 3,
#        4, 5, 3, 5, 4, 2, 2, 4, 3, 2, 2, 1, 3, 2, 2, 1, 3, 4, 3, 0, 5, 5,
# ...

# %%
X[y_means == 1]
# Out:
# array([[ 7.46, 38.  ],
#        [ 7.54, 40.  ],
#        [ 7.12, 39.  ],
#        [ 6.45, 38.  ],
#        [ 7.43, 33.  ],
#        [ 6.7 , 38.  ],
#        [ 6.29, 42.  ],
#        [ 6.69, 33.  ],
#        [ 8.42, 36.  ],
#        [ 7.7 , 32.  ],
#        [ 7.94, 31.  ],
#        [ 6.67, 31.  ],
#        [ 6.58, 30.  ],
#        [ 5.65, 35.  ],
#        [ 6.78, 39.  ],
#        [ 7.  , 30.  ],
#        [ 6.89, 35.  ],
#        [ 6.96, 31.  ],
#        [ 6.48, 33.  ],
#        [ 7.28, 37.  ],
#        [ 7.  , 39.  ],
#        [ 6.2 , 30.  ],
#        [ 7.16, 37.  ],
#        [ 6.81, 39.  ],
#        [ 7.66, 41.  ],
#        [ 6.32, 33.  ],
#        [ 6.4 , 34.  ],
#        [ 6.77, 42.  ],
#        [ 6.29, 34.  ],
#        [ 6.51, 37.  ],
#        [ 6.17, 37.  ],
#        [ 6.2 , 38.  ],
#        [ 7.72, 30.  ],
#        [ 6.22, 40.  ],
#        [ 7.51, 39.  ],
#        [ 7.3 , 42.  ],
#        [ 7.78, 33.  ],
#        [ 7.3 , 31.  ],
#        [ 6.67, 38.  ],
#        [ 8.19, 33.  ],
# ...

# %%
plt.scatter(X[y_means == 0,0], X[y_means == 0,1], color='red')
plt.scatter(X[y_means == 1,0], X[y_means == 1,1], color='blue')
plt.scatter(X[y_means == 2,0], X[y_means == 2,1], color='green')
plt.scatter(X[y_means == 3,0], X[y_means == 3,1], color='yellow')
plt.scatter(X[y_means == 4,0], X[y_means == 4,1], color='black')
plt.scatter(X[y_means == 5,0], X[y_means == 5,1], color='pink')
# plt.scatter(X[y_means == 6,0], X[y_means == 6,1], color='orange')
# plt.scatter(X[y_means == 7,0], X[y_means == 7,1], color='indigo')
# plt.scatter(X[y_means == 8,0], X[y_means == 8,1], color='violet')
# plt.scatter(X[y_means == 9,0], X[y_means == 9,1], color='brown')
# plt.scatter(X[y_means == 5,0], X[y_means == 5,1], color='pink')

# %% [markdown]
# #KMeans for 3D Data

# %%
from sklearn.datasets import make_blobs

centroids = [(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=200,cluster_std=cluster_std,centers=centroids,n_features=3,random_state=1)

# %%
X
# Out:
# array([[ 4.33424548,  3.32580419, -4.17497018],
#        [-3.32246719,  3.22171129, -4.625342  ],
#        [-6.07296862, -4.13459237,  2.6984613 ],
#        [ 6.90465871,  6.1110567 , -4.3409502 ],
#        [-2.60839207,  2.95015551, -2.2346649 ],
#        [ 5.88490881,  4.12271848, -5.86778722],
#        [-4.68484061, -4.15383935,  4.14048406],
#        [-1.82542929,  3.96089238, -3.4075272 ],
#        [-5.34385368, -4.95640314,  4.37999916],
#        [ 4.91549197,  4.70263812, -4.582698  ],
#        [-3.80108212, -4.81484358,  4.62471505],
#        [ 4.6735005 ,  3.65732421, -3.88561702],
#        [-6.23005814, -4.4494625 ,  5.79280687],
#        [-3.90232915,  2.95112294, -4.6949209 ],
#        [ 3.72744124,  5.31354772, -4.49681519],
#        [-3.3088472 ,  3.05743945, -3.81896126],
#        [ 2.70273021, -2.21732429,  3.17390257],
#        [ 4.06438286, -0.36217193,  3.214466  ],
#        [ 4.69268607, -2.73794194,  5.15528789],
#        [ 4.1210827 , -1.5438783 ,  3.29415949],
# ...

# %%
import plotly.express as px

fig = px.scatter_3d(x=X[:,0], y=X[:,1], z=X[:,2])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wcss = []

for i in range(1,11):
  km = KMeans(n_clusters=i)
  km.fit_predict(X)
  wcss.append(km.inertia_)

# %%
wcss
# Out:
# [11143.784324503365,
#  4122.40955760353,
#  2163.269450436297,
#  593.2516262404542,
#  544.0909257443524,
#  515.2847486662029,
#  486.1729997816662,
#  481.95412133678894,
#  429.98728427398095,
#  391.5221985594348]

# %%
plt.plot(range(1,11), wcss)

# %%
km = KMeans(n_clusters=4)

y_pred=km.fit_predict(X)

# %%
y_pred
# Out:
# array([2, 0, 1, 2, 0, 2, 1, 0, 1, 2, 1, 2, 1, 0, 2, 0, 3, 3, 3, 3, 1, 3,
#        0, 1, 1, 2, 0, 3, 2, 0, 3, 2, 2, 1, 0, 2, 1, 0, 3, 3, 1, 0, 1, 2,
#        0, 3, 3, 2, 0, 1, 2, 3, 3, 0, 1, 1, 0, 3, 3, 2, 1, 0, 0, 0, 3, 1,
#        3, 2, 1, 0, 3, 2, 2, 2, 1, 2, 2, 2, 1, 3, 0, 1, 0, 0, 1, 0, 2, 1,
#        1, 0, 2, 0, 0, 3, 0, 1, 1, 2, 1, 1, 2, 1, 1, 2, 0, 0, 0, 3, 3, 0,
#        3, 2, 3, 0, 3, 0, 1, 0, 3, 2, 1, 2, 3, 3, 0, 1, 3, 2, 3, 1, 3, 1,
#        0, 1, 2, 3, 3, 2, 0, 0, 1, 2, 2, 0, 1, 2, 2, 1, 0, 2, 0, 2, 3, 3,
#        2, 3, 1, 0, 3, 2, 2, 1, 1, 3, 3, 1, 1, 3, 3, 1, 2, 1, 2, 3, 2, 2,
#        0, 3, 3, 1, 0, 0, 3, 3, 3, 1, 0, 1, 2, 2, 0, 0, 2, 3, 3, 2, 0, 1,
#        3, 0], dtype=int32)

# %%
df = pd.DataFrame()

df['col1'] = X[:,0]
df['col2'] = X[:,1]
df['col3'] = X[:,2]
df['label'] = y_pred

# %%
fig = px.scatter_3d(df,x='col1', y='col2', z='col3', color='label')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
